# %% [markdown]
# ## Plotting figure 1 of Ong et al. 2025 Transient ASC Response under Climate Change including Meltwater

# %%
## NEED TO USED GADI JUPYTER - 4 nodes with 250gb mem total

# %%
import cosima_cookbook as cc
from dask.distributed import Client
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import numpy as np

import xarray as xr
import cmocean as cm
import cartopy.crs as ccrs
import cmocean as cm
import glob
import os

# %%
import matplotlib.dates as mdates
import datetime
import pandas as pd

# %%
# %matplotlib inline

# %%
from matplotlib import rc
rc('font', **{'size':25})
rc('text', usetex=False)
rc('xtick', labelsize=25) #20 
rc('ytick', labelsize=25) #20
rc('axes', titlesize=25)    # fontsize of the axes title
rc('axes', labelsize=25) #24    # fontsize of the x and y labels

# %%
session=cc.database.create_session()
expt = '01deg_jra55v13_ryf9091'

# %%
import dask.config
from dask.distributed import Client,LocalCluster
from dask_jobqueue import PBSCluster

c = Client()
c
# Out:
# <Client: 'tcp://127.0.0.1:46865' processes=7 threads=28, memory=125.19 GiB>

# %%
hu = cc.querying.getvar(expt='01deg_jra55v13_ryf9091', variable='hu', 
                          session=session, frequency='static',
                          attrs={'cell_methods': 'time: point'}, n=1).sel(yu_ocean = slice(-79,-60)).chunk({ 'yu_ocean':69, 'xu_ocean':360})
hu
# Out:
# <xarray.DataArray 'hu' (yu_ocean: 440, xu_ocean: 3600)> Size: 6MB
# dask.array<rechunk-merge, shape=(440, 3600), dtype=float32, chunksize=(69, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * xu_ocean  (xu_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.8 79.9 80.0
#   * yu_ocean  (yu_ocean) float64 4kB -78.98 -78.93 -78.89 ... -60.07 -60.02
#     geolon_c  (yu_ocean, xu_ocean) float32 6MB dask.array<chunksize=(69, 360), meta=np.ndarray>
#     geolat_c  (yu_ocean, xu_ocean) float32 6MB dask.array<chunksize=(69, 360), meta=np.ndarray>
# Attributes:
#     long_name:     ocean depth on u-cells
#     units:         m
#     valid_range:   [-1.e+09  1.e+09]
#     cell_methods:  time: point
#     ncfiles:       ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf909...
#     contact:       Andy Hogg
#     email:         andy.hogg@anu.edu.au
#     created:       2020-06-11
#     description:   0.1 degree ACCESS-OM2 global model configuration with JRA5...
# ...

# %%
# location limits of dataset - choosing slice near totten
#lon_lim = slice(-270, -230) #slice(30, 45)#
lat_lim = slice(-79, -60) #slice(-70, -65)

hu_region = hu.sel( yu_ocean = lat_lim)

# %%
exp_ctrl= '01deg_jra55v13_ryf9091'
exp_wthmp= '01deg_jra55v13_ryf9091_qian_wthmp'
exp_wthp= '01deg_jra55v13_ryf9091_qian_wthp'
lat_lim = slice(-79, -60)
lon_lim = slice(-279.99,80)

#### start with meltwater, wind and thermal experiment
expt = exp_wthmp

# %%
# We will use an annual average from 10 year in the RYF run
start_time_mw='2110-01-01 00:00:00' 
end_time_mw='2159-12-31 00:00:00'

flex_period = slice(start_time_mw, end_time_mw)

# %% [markdown]
# ## making ualong decade average fields

# %%
u = cc.querying.getvar(expt=expt, variable='tx_trans_int_z', 
                          session=session).sel(time=flex_period).sel(yt_ocean = slice(-79,-60)).chunk({ 'yt_ocean':69, 'xu_ocean':360})
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# ...

# %%
v = cc.querying.getvar(expt=expt, variable='ty_trans_int_z', 
                          session=session).sel(yu_ocean = slice(-79,-60)).sel(time=flex_period).chunk({ 'yu_ocean':69, 'xt_ocean':360})
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# ...

# %%
## due to bug in diagnostic file, ty_trans_int_z diagnostic is incorrect (https://github.com/mom-ocean/MOM5/pull/331)
## correct using  ```ty_trans_int_z_corrected = ty_trans_int_z - tx_trans_int_x```
ty_trans_int_z_error = cc.querying.getvar(expt=expt, variable='ty_trans_int_z', 
                          session=session).sel(yu_ocean = slice(-79,-60)).sel(time=flex_period).chunk({ 'yu_ocean':69, 'xt_ocean':360})
ty_trans_int_z_vals = ty_trans_int_z_error.values - u.values
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# ...

# %%
v = xr.DataArray(ty_trans_int_z_vals, dims = ['time','yu_ocean','xt_ocean'],
                 coords = dict(xt_ocean = ('xt_ocean', ty_trans_int_z_error.xt_ocean.data), yu_ocean = ('yu_ocean', hu.yu_ocean.data), \
                               time = ('time',u.time.data)))

# %%
#mask_shelf = xr.where(hu<1000 , True, False)
#mask_slope = xr.where(hu>1000, True, False)
cluster_mask_shelfwcanyons = ~xr.open_mfdataset('/home/561/qo9901/MW-perturb-ASC/nc_files/600misobath_sans_canyons_cluster_mask_xr_accessom201.nc')
## note inverse in cluster_mask_shelfwcanyons
cluster_mask_shelfwcanyons= cluster_mask_shelfwcanyons.assign_coords(xu_ocean = ('xu_ocean', hu.xu_ocean.data), yu_ocean = ('yu_ocean', hu.yu_ocean.data))
# cluster_mask_shelfwcanyons == True: Shelf

# %%
# defining B-grid using xgcm
path_to_folder = '/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091/output000/ocean/'
ocean_grid = xr.open_mfdataset(path_to_folder+'ocean_grid.nc', combine='by_coords')

# %%
# NEEDload coordinates and grid specifications
geolat_t = cc.querying.getvar(expt, 'geolat_t', session=session, n=1)
geolon_t = cc.querying.getvar(expt, 'geolon_t', session=session, n=1)

dxt = cc.querying.getvar(expt=expt, variable='dxt', session=session, frequency='static', n=1)
dyt = cc.querying.getvar(expt=expt, variable='dyt', session=session, frequency='static', n=1)

dxu = cc.querying.getvar(expt=expt, variable='dxu', session=session, frequency='static', n=1)
dyu = cc.querying.getvar(expt=expt, variable='dyu', session=session, frequency='static', n=1)

# %%
# coordinates
lat_t = geolat_t.sel( xt_ocean= lon_lim,yt_ocean=lat_lim)
lon_t = geolon_t.sel(xt_ocean= lon_lim, yt_ocean=lat_lim)

dxt_lim = dxt.sel(xt_ocean= lon_lim,yt_ocean=lat_lim)
dyt_lim = dyt.sel(xt_ocean= lon_lim,yt_ocean=lat_lim)

dxu_lim = dxu.sel(xu_ocean= lon_lim,yu_ocean=lat_lim)
dyu_lim = dyu.sel(xu_ocean= lon_lim,yu_ocean=lat_lim)

# %%
## need to run seperately or it will crash
import xgcm
coordinates = xr.merge([dxt_lim, dyt_lim, dxu_lim, dyu_lim])

# %%
# u.isel(time = 0), v.isel(time = 0), 
vel = xr.merge([hu,coordinates,ocean_grid.sel(xt_ocean= lon_lim,xu_ocean= lon_lim, yt_ocean=lat_lim, yu_ocean = lat_lim).isel(time = 0)],compat='override')# time is flex_period before

# %%
vel = vel.drop_vars('time')

# %%
vel.coords['xt_ocean'].attrs.update(axis='X')
vel.coords['xu_ocean'].attrs.update(axis='X', c_grid_axis_shift=0.5, periodic=True)
vel.coords['yt_ocean'].attrs.update(axis='Y')
vel.coords['yu_ocean'].attrs.update(axis='Y', c_grid_axis_shift=0.5)
metrics = {
    ('X',): ['dxt', 'dxu'], # X distances
    ('Y',): ['dyt', 'dyu'], # Y distances
    ('X', 'Y'): ['area_t', 'area_u'] # Areas
}

# %%
grid = xgcm.Grid(vel, periodic=['X'], metrics = metrics,boundary='extend')

# %%
# Take gradient and move to u grid
# Simple gradient over one grid cell. 
# In latitudinal direction, we need to specify what happens at the boundary.
dhu_dx = grid.interp( grid.diff(vel.hu, 'X') / grid.interp(vel.dxu, 'X'), 'X')#, 'Y', boundary='extend')
dhu_dy = grid.interp( grid.diff(vel.hu, 'Y', boundary='extend') / grid.interp(vel.dyt, 'X'), 'Y', boundary='extend')# 'X')

# %%
# Calculate the magnitude of the topographic slope
slope = np.sqrt(dhu_dx**2 + dhu_dy**2).rename('slope')

# %% [markdown]
# ## Calculation of decadal means - splitting in x and then calculating time mean -- we end up only using final 10 years of experiment

# %%
def calc_trans_along_decademean(tt, chunk_size, u_input, v_input):
    
    u_t = grid.interp(u_input.isel(time = slice(tt*chunk_size, chunk_size*(tt+1))), axis = 'Y')#.where(cluster_mask_access == True)#.where(mask_region == True).load()
    v_t = grid.interp(v_input.isel(time = slice(tt*chunk_size, chunk_size*(tt+1))), axis = 'X')#.where(cluster_mask_access == True)#.where(mask_region == True).load()
    
    u_comp = (u_t*dhu_dy/slope)#.__xarray_dataarray_variable__#.compute()
    v_comp = (v_t*dhu_dx/slope)#.__xarray_dataarray_variable__#.compute()
    u_along = u_comp.chunk({ 'yu_ocean':100, 'xu_ocean':50}) - v_comp.chunk({ 'yu_ocean':100, 'xu_ocean':50})
    u_along_tt = u_along.mean(dim = 'time').load()#.values
    print(tt)
    return u_along_tt

# %%
## with meltwater experiment first
ualong_x_tmean = []
## array of decades with ualong mean
chunk_size = 3600
for tt in range(4,5): # final of 5 decades
    ualong_x_elem = calc_trans_along_decademean(tt, 120, u,v)
    ualong_x_tmean.append(ualong_x_elem)
# Out:
# 2025-04-17 13:16:31,482 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2025-04-17 13:16:34,822 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 4

# %%
ualong_decademean = ualong_x_tmean[0]#.assign_coords({'decade': 4}).expand_dims('decade')
                              
ualong_decademean = ualong_decademean#.rename_vars({'__xarray_dataarray_variable__':'trans_along'})
ualong_decademean = (ualong_decademean/1035e6)#.assign_attrs(
#    units="Sv", description= 'Time-mean along slope velocity for each decade of MW expriment: ' + expt )
ualong_decademean
# Out:
# <xarray.DataArray (yu_ocean: 440, xu_ocean: 3600)> Size: 6MB
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [0.18492968, 0.16854481, 0.14568506, ..., 0.3067037 , 0.24000165,
#         0.21563794],
#        [0.07721861, 0.12782961, 0.13483779, ..., 0.33846417, 0.25301588,
#         0.208323  ],
#        [0.03772881, 0.10690867, 0.1238504 , ..., 0.3429768 , 0.24633716,
#         0.19600286]], dtype=float32)
# Coordinates:
#   * xu_ocean  (xu_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.8 79.9 80.0
#   * yu_ocean  (yu_ocean) float64 4kB -80.0 -78.93 -78.89 ... -60.07 -60.02

# %%
ualong_decademean_wthmp = ualong_decademean#.plot()

# %%
## with thermal and wind experiment, no meltwater

u_wthp = cc.querying.getvar(expt=exp_wthp, variable='tx_trans_int_z', 
                          session=session).sel(time=flex_period).sel(yt_ocean = slice(-79,-60)).chunk({ 'yt_ocean':69, 'xu_ocean':360})

## due to bug in diagnostic file, ty_trans_int_z diagnostic is incorrect (https://github.com/mom-ocean/MOM5/pull/331)
## correct using  ```ty_trans_int_z_corrected = ty_trans_int_z - tx_trans_int_x```
ty_trans_int_z_error = cc.querying.getvar(expt=exp_wthp, variable='ty_trans_int_z', 
                          session=session).sel(yu_ocean = slice(-79,-60)).sel(time=flex_period).chunk({ 'yu_ocean':69, 'xt_ocean':360})
ty_trans_int_z_vals = ty_trans_int_z_error.values - u_wthp.values

v_wthp = xr.DataArray(ty_trans_int_z_vals, dims = ['time','yu_ocean','xt_ocean'],
                 coords = dict(xt_ocean = ('xt_ocean', ty_trans_int_z_error.xt_ocean.data), yu_ocean = ('yu_ocean', hu.yu_ocean.data), \
                               time = ('time',u.time.data)))
ualong_x_tmean = []
## array of decades with ualong mean
chunk_size = 3600
for tt in range(4,5): # total 5 decades
    ualong_x_elem = calc_trans_along_decademean(tt, 120, u_wthp,v_wthp)
    ualong_x_tmean.append(ualong_x_elem)
ualong_decademean = ualong_x_tmean[0]#.assign_coords({'decade': 4}).expand_dims('decade')
ualong_decademean_wthp = (ualong_decademean/1035e6)
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# ...

# %%
## with control experiment

u_ctrl= cc.querying.getvar(expt=exp_ctrl, variable='tx_trans_int_z', 
                          session=session).sel(time=flex_period).sel(yt_ocean = slice(-79,-60)).chunk({ 'yt_ocean':69, 'xu_ocean':360})
## due to bug in diagnostic file, ty_trans_int_z diagnostic is incorrect (https://github.com/mom-ocean/MOM5/pull/331)
## correct using  ```ty_trans_int_z_corrected = ty_trans_int_z - tx_trans_int_x```
ty_trans_int_z_error = cc.querying.getvar(expt=exp_ctrl, variable='ty_trans_int_z', 
                          session=session).sel(yu_ocean = slice(-79,-60)).sel(time=flex_period).chunk({ 'yu_ocean':69, 'xt_ocean':360})
ty_trans_int_z_vals = ty_trans_int_z_error.values - u_ctrl.values

v_ctrl = xr.DataArray(ty_trans_int_z_vals, dims = ['time','yu_ocean','xt_ocean'],
                 coords = dict(xt_ocean = ('xt_ocean', ty_trans_int_z_error.xt_ocean.data), yu_ocean = ('yu_ocean', hu.yu_ocean.data), \
                               time = ('time',u.time.data)))

ualong_x_tmean = []
## array of decades with ualong mean
chunk_size = 3600
for tt in range(4,5): # total 5 decades
    ualong_x_elem = calc_trans_along_decademean(tt, 120, u_ctrl,v_ctrl)
    ualong_x_tmean.append(ualong_x_elem)
ualong_decademean = ualong_x_tmean[0]#.assign_coords({'decade': 4}).expand_dims('decade')
ualong_decademean_ctrl = (ualong_decademean/1035e6)
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataset.py:271: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# ...

# %% [markdown]
# ## Plotting begins

# %%
cd Antarctic-Eddy-Res-Compare
# Out:
# [Errno 2] No such file or directory: 'Antarctic-Eddy-Res-Compare'
# /home/561/qo9901/Antarctic-Eddy-Res-Compare

# %%
import cmocean
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# %%
## importing masks for clusters

cluster_mask_access = xr.open_mfdataset('largest_3cluster_mask_xr_accessom201.nc')
cluster_mask_access= cluster_mask_access.assign_coords(xu_ocean = ('xu_ocean', hu.xu_ocean.data), yu_ocean = ('yu_ocean', hu.yu_ocean.data)).__xarray_dataarray_variable__

# %%
mask_bath_slopeshelf = xr.where((hu_region <2600),True,False)

# %%
land_mask = np.squeeze(hu.values)
land_mask = land_mask * 0
land_mask[np.isnan(land_mask)] = 1
yu_ocean = hu.yu_ocean.values
xu_ocean = hu.xu_ocean.values
land_mask_masked = np.ma.masked_where((land_mask==0),land_mask)
# make land go all the way to -90S:
land_mask_lat = hu.yu_ocean.values
land_mask_lat[0] = -80

# %%
levels_ualong = np.arange(-0.1,0.11,0.01)
levels_ualong = np.arange(-0.4,0.41,0.01)

# %%
def changeline_cs(linestyle):
    cs.monochrome = True
    for col,  ls in zip(cs.collections,cs._process_linestyles(linestyle)):
        col.set_linestyle(ls)
        col.set_edgecolor('k')
        #col.set_linewidth(2)

# %%
hu_region = hu_region#.where(cluster_mask_access == True)

# %%
cluster_mask_shelfwcanyons = ~xr.open_mfdataset('/home/561/qo9901/MW-perturb-ASC/nc_files/600misobath_sans_canyons_cluster_mask_xr_accessom201.nc')
## note inverse in cluster_mask_shelfwcanyons
cluster_mask_shelfwcanyons= cluster_mask_shelfwcanyons.assign_coords(xu_ocean = ('xu_ocean', hu.xu_ocean.data), yu_ocean = ('yu_ocean', hu.yu_ocean.data))
# cluster_mask_shelfwcanyons == True: Shelf

# %%
lat_slice_ross = slice(-80, -65)
lon_slice_ross = slice(-200, -150)
lat_slice_WA = slice(-77, -65) # -80
lon_slice_WA = slice(-130, -70)
lat_slice_WEA = slice(-75, -65) #-80
lon_slice_WEA = slice(-25, 40)
lat_slice_east = slice(-67.5, -61) # calculation EA is -67,-63, modified for the aspect ratio
lon_slice_east = slice(-270, -230)

# %%
def add_regional(lat_slice, lon_slice, axis):
    left, bottom, width, height \
        = (lon_slice.start, lat_slice.start, abs(lon_slice.stop - lon_slice.start)\
           , abs(lat_slice.stop-lat_slice.start))
    axis.add_patch(
        patches.Rectangle(
        xy=(left, bottom),  # point of origin.
        width=width, height=height, linewidth=4,
        color='gray', fill=False, zorder = 3))   
    return

# %%
import matplotlib.patches as patches

# %%
#### MODIFIES FOR THESIS COLORBAR
fig, ax = plt.subplots(nrows =4 ,figsize = (30,25))

# accessom2-01
cmap = ualong_decademean_ctrl.where(cluster_mask_access == True).plot.contourf(levels  = levels_ualong, cmap = cmocean.cm.delta, add_colorbar = False, ax = ax[0])
#cs = hu_region.where(hu_region < 2600).plot.contour(levels  = [2500], color = 'k', ax = ax[0])
#changeline_cs('solid')
cs = cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).plot.contour(n = 1, color = 'k', ax = ax[0], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')
ax[0].set_ylabel('')
ax[0].contourf(hu.xu_ocean, land_mask_lat, land_mask_masked, colors='darkgrey', zorder=2)
ax[0].text(0.01,0.1,'Control',transform=ax[0].transAxes)
ax[0].set_xlabel('')
ax[0].text(0.001,0.9,'(a)', transform=ax[0].transAxes, fontweight = 'bold')


cb_ax = fig.add_axes([0.1, 0.9, 0.8, 0.02])
cbar = plt.colorbar(cmap, orientation = 'horizontal', cax = cb_ax)
cbar.ax.xaxis.set_ticks_position('top')
cbar.ax.xaxis.set_label_position('top')
cbar.set_label("$T_{along}$ (Sv)", labelpad=20)

cmap = (ualong_decademean_wthmp ).where(cluster_mask_access == True).plot.contourf(levels  = levels_ualong, cmap = cmocean.cm.delta, add_colorbar = False, ax = ax[1])
#np.flip(deptho, 0).plot.contour(levels  = np.arange(0,4000,500), cmap = 'gray_r' , ax = ax[1]) # shallow is dark ' Greys deep is dark
cs = cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).plot.contour(n = 1, color = 'k', ax = ax[1], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')

ax[1].contourf(hu.xu_ocean, land_mask_lat, land_mask_masked, colors='darkgrey', zorder=2)
ax[1].set_ylim([-80,-60])
#ax[1].text(0.01,0.1,'All Forcing \nExperiment',transform=ax[1].transAxes)
ax[1].text(0.01,0.1,'Wind + Thermal + Meltwater \nExperiment',transform=ax[1].transAxes)

ax[1].set_ylabel('')
ax[1].set_xlabel('')
ax[1].text(0.001,0.9,'(b)', transform=ax[1].transAxes, fontweight = 'bold')

cmap = (ualong_decademean_wthp - ualong_decademean_ctrl).where(cluster_mask_access == True).plot.contourf(levels  = levels_ualong, add_colorbar = False, ax = ax[2])
#np.flip(deptho, 0).plot.contour(levels  = np.arange(0,4000,500), cmap = 'gray_r' , ax = ax[1]) # shallow is dark ' Greys deep is dark
cs =cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).plot.contour(n = 1, color = 'k', ax = ax[2], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')

ax[2].contourf(hu.xu_ocean, land_mask_lat, land_mask_masked, colors='darkgrey', zorder=2)
ax[2].set_ylim([-80,-60])
ax[2].text(0.01,0.1,'Wind + Thermal \nComponent',transform=ax[2].transAxes)
ax[2].set_ylabel('')
ax[2].set_xlabel('')
ax[2].text(0.001,0.9,'(c)', transform=ax[2].transAxes, fontweight = 'bold')

cmap = (ualong_decademean_wthmp -ualong_decademean_ctrl ).where(cluster_mask_access == True).plot.contourf(levels  = levels_ualong, add_colorbar = False, ax = ax[3])
#np.flip(deptho, 0).plot.contour(levels  = np.arange(0,4000,500), cmap = 'gray_r' , ax = ax[1]) # shallow is dark ' Greys deep is dark
cs = cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).plot.contour(n = 1, color = 'k', ax = ax[3], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')

ax[3].contourf(hu.xu_ocean, land_mask_lat, land_mask_masked, colors='darkgrey', zorder=2)
ax[3].set_ylim([-80,-60])
ax[3].text(0.01,0.1,'Meltwater \nComponent',transform=ax[3].transAxes)
ax[3].set_ylabel('')
ax[3].set_xlabel('')
ax[3].text(0.001,0.9,'(d)', transform=ax[3].transAxes, fontweight = 'bold')


add_regional(lat_slice_ross, lon_slice_ross, ax[3])
add_regional(lat_slice_east, lon_slice_east, ax[3])
add_regional(lat_slice_WA, lon_slice_WA, ax[3])
add_regional(lat_slice_WEA, lon_slice_WEA, ax[3])
ax[3].annotate('Ross',(lon_slice_ross.start+ 0.5,lat_slice_ross.stop -1.5), transform=ax[3].transAxes, color = 'gray', fontsize = 20)
ax[3].annotate('East Antarctica',(lon_slice_east.start+ 0.5,lat_slice_east.stop -1.5), transform=ax[3].transAxes, color = 'gray', fontsize = 20)
ax[3].annotate('Weddell-Prydz Bay',(lon_slice_WEA.start+ 0.5,lat_slice_WEA.stop -1.5), transform=ax[3].transAxes, color = 'gray', fontsize = 20)
ax[3].annotate('West Antarctica',(lon_slice_WA.start+ 0.5,lat_slice_WA.stop -1.5), transform=ax[3].transAxes, color = 'gray', fontsize = 20)

cb_ax = fig.add_axes([0.1, 0.05, 0.8, 0.02])
cbar = plt.colorbar(cmap, label = '$\Delta T_{along}$ (Sv)', orientation = 'horizontal', cax = cb_ax, pad = 0.01)
#cbar.set_ticks(np.arange(-0.1,0.125,0.025))

for box in range(4):
    ax[box].yaxis.set_major_formatter(LatitudeFormatter())
    ax[box].xaxis.set_major_formatter(LongitudeFormatter())

# %%
fig, ax = plt.subplots(nrows =4 ,figsize = (30,25))

# accessom2-01
cmap = ualong_decademean_ctrl.where(cluster_mask_access == True).plot.contourf(levels  = levels_ualong, add_colorbar = False, ax = ax[0])
#cs = hu_region.where(hu_region < 2600).plot.contour(levels  = [2500], color = 'k', ax = ax[0])
#changeline_cs('solid')
cs = cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).plot.contour(n = 1, color = 'k', ax = ax[0], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')
ax[0].set_ylabel('')
ax[0].contourf(hu.xu_ocean, land_mask_lat, land_mask_masked, colors='darkgrey', zorder=2)
ax[0].text(0.01,0.1,'Control',transform=ax[0].transAxes)
ax[0].set_xlabel('')
ax[0].text(0.001,0.9,'(a)', transform=ax[0].transAxes, fontweight = 'bold')


cmap = (ualong_decademean_wthmp).where(cluster_mask_access == True).plot.contourf(levels  = levels_ualong, add_colorbar = False, ax = ax[1])
#np.flip(deptho, 0).plot.contour(levels  = np.arange(0,4000,500), cmap = 'gray_r' , ax = ax[1]) # shallow is dark ' Greys deep is dark
cs = cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).plot.contour(n = 1, color = 'k', ax = ax[1], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')

ax[1].contourf(hu.xu_ocean, land_mask_lat, land_mask_masked, colors='darkgrey', zorder=2)
ax[1].set_ylim([-80,-60])
#ax[1].text(0.01,0.1,'All Forcing \nExperiment',transform=ax[1].transAxes)
ax[1].text(0.01,0.1,'Wind + Thermal + Meltwater \nExperiment',transform=ax[1].transAxes)

ax[1].set_ylabel('')
ax[1].set_xlabel('')
ax[1].text(0.001,0.9,'(b)', transform=ax[1].transAxes, fontweight = 'bold')

cmap = (ualong_decademean_wthp - ualong_decademean_ctrl).where(cluster_mask_access == True).plot.contourf(levels  = levels_ualong, add_colorbar = False, ax = ax[2])
#np.flip(deptho, 0).plot.contour(levels  = np.arange(0,4000,500), cmap = 'gray_r' , ax = ax[1]) # shallow is dark ' Greys deep is dark
cs =cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).plot.contour(n = 1, color = 'k', ax = ax[2], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')

ax[2].contourf(hu.xu_ocean, land_mask_lat, land_mask_masked, colors='darkgrey', zorder=2)
ax[2].set_ylim([-80,-60])
ax[2].text(0.01,0.1,'Wind + Thermal \nComponent',transform=ax[2].transAxes)
ax[2].set_ylabel('')
ax[2].set_xlabel('')
ax[2].text(0.001,0.9,'(c)', transform=ax[2].transAxes, fontweight = 'bold')

cmap = (ualong_decademean_wthmp -ualong_decademean_ctrl ).where(cluster_mask_access == True).plot.contourf(levels  = levels_ualong, add_colorbar = False, ax = ax[3])
#np.flip(deptho, 0).plot.contour(levels  = np.arange(0,4000,500), cmap = 'gray_r' , ax = ax[1]) # shallow is dark ' Greys deep is dark
cs = cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).plot.contour(n = 1, color = 'k', ax = ax[3], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')

ax[3].contourf(hu.xu_ocean, land_mask_lat, land_mask_masked, colors='darkgrey', zorder=2)
ax[3].set_ylim([-80,-60])
ax[3].text(0.01,0.1,'Meltwater \nComponent',transform=ax[3].transAxes)
ax[3].set_ylabel('')
ax[3].set_xlabel('')
ax[3].text(0.001,0.9,'(d)', transform=ax[3].transAxes, fontweight = 'bold')


add_regional(lat_slice_ross, lon_slice_ross, ax[3])
add_regional(lat_slice_east, lon_slice_east, ax[3])
add_regional(lat_slice_WA, lon_slice_WA, ax[3])
add_regional(lat_slice_WEA, lon_slice_WEA, ax[3])
ax[3].annotate('Ross',(lon_slice_ross.start+ 0.5,lat_slice_ross.stop -1.5), transform=ax[3].transAxes, color = 'gray', fontsize = 20)
ax[3].annotate('East Antarctica',(lon_slice_east.start+ 0.5,lat_slice_east.stop -1.5), transform=ax[3].transAxes, color = 'gray', fontsize = 20)
ax[3].annotate('Weddell-Prydz Bay',(lon_slice_WEA.start+ 0.5,lat_slice_WEA.stop -1.5), transform=ax[3].transAxes, color = 'gray', fontsize = 20)
ax[3].annotate('West Antarctica',(lon_slice_WA.start+ 0.5,lat_slice_WA.stop -1.5), transform=ax[3].transAxes, color = 'gray', fontsize = 20)

cb_ax = fig.add_axes([0.1, 0.05, 0.8, 0.02])
cbar = plt.colorbar(cmap, label = '$T_{along}$ (Sv)', orientation = 'horizontal', cax = cb_ax, pad = 0.01)
#cbar.set_ticks(np.arange(-0.1,0.125,0.025))

for box in range(4):
    ax[box].yaxis.set_major_formatter(LatitudeFormatter())
    ax[box].xaxis.set_major_formatter(LongitudeFormatter())

# %%
## supplementary fig
from matplotlib import rc
rc('font', **{'size':18})
rc('text', usetex=False)
rc('xtick', labelsize=18) #20 
rc('ytick', labelsize=18) #20
rc('axes', titlesize=18)    # fontsize of the axes title
rc('axes', labelsize=18) #24    # fontsize of the x and y labels
fig, ax = plt.subplot_mosaic("ab;cd", figsize = (12,12))

cmap = (ualong_decademean_wthmp - ualong_decademean_wthp).where(cluster_mask_access == True).sel(xu_ocean = lon_slice_east, yu_ocean = lat_slice_east).plot.contourf(levels  = levels_ualong, add_colorbar = False, ax = ax['a'])
cs = cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).sel(xu_ocean = lon_slice_east, yu_ocean = lat_slice_east).plot.contour(n = 1, color = 'g', ax = ax['a'], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')
ax['a'].set_yticks([-66,-64, -62])
ax['a'].set_xticks([-265,-250, -235])
ax['a'].set_xlabel('')
ax['a'].set_ylabel('')
ax['a'].text(0.4,0.85,'East Antarctica', transform=ax['a'].transAxes, fontweight = 'bold')
#ax['E'].text(0.01,0.03,'(e)', transform=ax['E'].transAxes, fontweight = 'bold')



cmap = (ualong_decademean_wthmp - ualong_decademean_wthp).where(cluster_mask_access == True).sel(xu_ocean = lon_slice_ross, yu_ocean = lat_slice_ross).plot.contourf(levels  = levels_ualong, add_colorbar = False, ax = ax['b'])
cs = cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).sel(xu_ocean = lon_slice_ross, yu_ocean = lat_slice_ross).plot.contour(n = 1,color = 'g', ax = ax['b'], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')
ax['b'].set_yticks([-78,-74,-70,-66])
ax['b'].set_xticks([-200,-180,-160])

ax['b'].set_xlabel('')
ax['b'].set_ylabel('')
ax['b'].text(0.77,0.85,'Ross', transform=ax['b'].transAxes, fontweight = 'bold')
#ax['F'].text(0.01,0.03,'(f)', transform=ax['F'].transAxes, fontweight = 'bold')


cmap = (ualong_decademean_wthmp - ualong_decademean_wthp).where(cluster_mask_access == True).sel(xu_ocean = lon_slice_WA, yu_ocean = lat_slice_WA).plot.contourf(levels  = levels_ualong, add_colorbar = False, ax = ax['c'])
cs = cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).sel(xu_ocean = lon_slice_WA, yu_ocean = lat_slice_WA).plot.contour(n = 1, color = 'g', ax = ax['c'], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')

ax['c'].set_yticks([-74,-70,-66])
ax['c'].set_xlabel('')
ax['c'].set_ylabel('')
ax['c'].text(0.3,0.85,'West Antarctica', transform=ax['c'].transAxes, fontweight = 'bold')
#ax['G'].text(0.01,0.03,'(g)', transform=ax['G'].transAxes, fontweight = 'bold')


cmap = (ualong_decademean_wthmp - ualong_decademean_wthp).where(cluster_mask_access == True).sel(xu_ocean = lon_slice_WEA, yu_ocean = lat_slice_WEA).plot.contourf(levels  = levels_ualong, add_colorbar = False, ax = ax['d'])
cs =cluster_mask_shelfwcanyons.__xarray_dataarray_variable__.where(cluster_mask_access == True).sel(xu_ocean = lon_slice_WEA, yu_ocean = lat_slice_WEA).plot.contour(n = 1, color = 'g', ax = ax['d'], linestyle = 'dashed') #conventional definition for ASC
changeline_cs('dashed')
    
ax['d'].set_xlabel('')
ax['d'].set_ylabel('')
ax['d'].set_yticks([-73,-70,-67])
ax['d'].text(0.15,0.15,'Weddell - Prydz Bay', transform=ax['d'].transAxes, fontweight = 'bold')

#fig.supxlabel('Longitude', y = 0.0725)

for letter in list(map(chr, range(ord('a'), ord('d')+1))):
    ax[letter].yaxis.set_major_formatter(LatitudeFormatter())
    ax[letter].xaxis.set_major_formatter(LongitudeFormatter())
    ax[letter].text(0.01,0.93,'(' + letter + ')', \
                transform=ax[letter].transAxes, fontweight = 'bold')

#plt.tight_layout()

cb_ax = fig.add_axes([0.1, 0.05, 0.8, 0.02]) #[0.1, -0.01, 0.8, 0.02])
cbar = plt.colorbar(cmap, label = '$T_{along}$ (Sv)', orientation = 'horizontal', cax = cb_ax)
cbar.set_ticks(np.arange(-0.3,0.35,0.1))
